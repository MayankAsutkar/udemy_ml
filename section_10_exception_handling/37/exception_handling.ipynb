# %% [markdown]
# exception handling - > allows u to handle errors and take correct actions without stopping the execution of the program

# %%
# """
#     What are exceptions?
#     events -> disrupt normal flow
# """

### zero division
### filenotfound error
### value error
### type error

# %%
print(10/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(10/0)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Exception try,except block

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
try:
    a=b
except :
    print("The variable has not been assigned")
# Out:
# The variable has not been assigned

# %%
try:
    a=b
except NameError as ex:
    print(ex)
## here nameerror  is responsible for catching the errors
# Out:
# name 'b' is not defined

# %%
result = 1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 result = 1/0
#
# ZeroDivisionError: division by zero

# %%
try:
    result = 1/0
except ZeroDivisionError as ex:
    print(ex)
    print("Please enter the denominator as non-zero")
# Out:
# division by zero
# Please enter the denominator as non-zero

# %%
### nameError ,value error , division error and much more are derived ffrom same parent class

# %%
try: 
    a = b
except ZeroDivisionError as ex:
    print(ex)
except Exception as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
try: 
    a = b
except ZeroDivisionError as ex:
    print(ex)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 try:
# ----> 2     a = b
#       3 except ZeroDivisionError as ex:
#       4     print(ex)
#
# NameError: name 'b' is not defined

# %%
try:
    num = int(input("Enter a number"))
    result = 10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("You cannot have denomi as zero") 
except Exception as ex:
    print(ex)

# %% [markdown]
# ## try , except , else block

# %%
try: 
    num = int(input("Enter a number"))
    res = 10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("You cannot have denomi as zero") 
except Exception as ex:
    print(ex)
else:
    print(f"The result is {result}")
# Out:
# The result is 0.3125

# %%
## try,except,else, and finally

try: 
    num = int(input("Enter a number"))
    res = 10/num
except ValueError:
    print("This is not a valid number")
except ZeroDivisionError:
    print("You cannot have denomi as zero") 
except Exception as ex:
    print(ex)
else:
    print(f"The result is {result}")
finally:
    print("Execution is complete")
    
## finally block gets executed regardless of error caught or not but else vlock gets executed only if there is no error
# Out:
# You cannot have denomi as zero
# Execution is complete

# %%
### File handling and exception handling

try:
    file = open('example1.txt','r')
    content = file.read()
    print(content)
except FileNotFoundError:
    print("The file does not exist")
finally:
    if 'file' in locals() or not file.closed():
        file.close()
        print("file closed")
# Out:
# hi idiots
# how's the josh
# file closed

# %%
### File handling and exception handling

try:
    file = open('example.txt','r')
    content = file.read()
    print(content)
except FileNotFoundError:
    print("The file does not exist")
finally:
    if 'file' in locals() or not file.closed():
        file.close()
        print("file closed")
# Out:
# The file does not exist
# file closed
