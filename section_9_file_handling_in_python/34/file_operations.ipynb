# %% [markdown]
# Read and write files

# %%
with open('example.txt','r') as file:
    content = file.read()
    print(content)
# Out:
# Hi
# maja aa rha hai
# tu kaisa hai

# %% [markdown]
# ## read a file line by line

# %%
with open('example.txt','r') as file:
    for line in file:
        print(line.strip()) ### strip removes the newline character
# Out:
# Hi
# maja aa rha hai
# tu kaisa hai

# %% [markdown]
# ## writing a file(overwriting)

# %%
with open('example.txt','w') as file:
    file.write('Hello World\n')
    file.write('This is a new line.')

# %% [markdown]
# # write a file without overwriting

# %%
with open('example.txt','a') as file:
    file.write("\nappend operation taking place")

# %% [markdown]
# ### wring a list of lines to a file

# %%
lines = ['First line \n','Second line \n','Third line\n']
with open('example.txt','a') as file:
    file.writelines(lines)

# %% [markdown]
# ### binary files

# %%
data =b'\x00\x01\x01\x03\x04'
with open('example.bin','wb') as file: ## wb meanns write bin
    file.write(data)

# %%
with open('example.bin','rb') as file: ## wb meanns write bin
    content = file.read()
    print(content)
# Out:
# b'\x00\x01\x01\x03\x04'

# %% [markdown]
# ### rwading a content from source t4ext file and write to  destination text file

# %%
with open('example.txt','r') as source_file:
    content = source_file.read()
    
with open('destination.txt','w') as destination_file:
    destination_file.write(content)

# %% [markdown]
# ### read a text file and count the number of lines, words, and characters.

# %%
def count_text_file(file_path):
    with open(file_path,'r') as file:
        lines = file.readlines()
        line_count = len(lines)
        word_count = sum(len(line.split()) for line in lines)
        char_count = sum(len(line) for line in lines)
    return char_count, word_count, line_count

file_path = 'example.txt'
lines,words,characters = count_text_file(file_path)
print(f'lines:{lines}, Words:{words}, characters:{characters}')
# Out:
# lines:156, Words:23, characters:6

# %% [markdown]
# ### writing and then reading a file

# %% [markdown]
# w+ mode in py is used to open a file  for both reading and writing. If the file does not exist, it will be created. If the file exists, its content is truncated (i.e. file is overwritten).

# %%
with open('example.txt','w+') as file:
    file.write("Hello world\n")
    file.write("This is a new line \n")
    
    ## move the file cursor to the beginning
    file.seek(0)
    
    ## reading the content of the file
    content = file.read()
    print(content)
# Out:
# Hello world
# This is a new line
