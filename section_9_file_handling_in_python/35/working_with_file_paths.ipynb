# %% [markdown]
# ### creating a new directory

# %%
import os
new_dir = "package"
os.mkdir(new_dir)
print(f"directory:{new_dir} is created")
# Out:
# directory:package is created

# %% [markdown]
# ### listing files and directories

# %%
items = os.listdir('.')
print(items)
# Out:
# ['package', 'working_with_file_paths.ipynb']

# %% [markdown]
# ### joining paths

# %%
dir_name = "folder"
file_name="file.txt"
full_path = os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
dir_name = "folder"
file_name="file.txt"
full_path = os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# c:\Users\mayan\OneDrive\Documents\GitHub\udemy_ml\section_9_file_handling_in_python\35\folder\file.txt

# %%
path = 'example1.txt'
if os.path.exists(path):
    print(f"The path {path} exists")
else:
    print(f"The path {path} doesn't exists")
# Out:
# The path example1.txt doesn't exists

# %% [markdown]
# ### checking if the path is file or directory

# %%
path = 'package'
if os.path.isfile(path):
    print(f"The path {path} is a file")
elif os.path.isdir(path):
    print(f"The path {path} is a directory")
else:
    print(f"The path {path} is neither a file nor a directory.")
# Out:
# The path package is a directory

# %% [markdown]
# ### getting the absolute path

# %%
relative_path = 'package'
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# c:\Users\mayan\OneDrive\Documents\GitHub\udemy_ml\section_9_file_handling_in_python\35\package
