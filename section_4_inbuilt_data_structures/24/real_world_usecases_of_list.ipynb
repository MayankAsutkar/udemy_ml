# %%
to_do_list = ["Buy Groceries","clean the house","pay_bills"]

## adding to task

to_do_list.append("scheduled meeting")
to_do_list.append("Go for a Run")

## removing a completed task
to_do_list.remove("clean the house")

## checking if the task is in the list

if "pay_bills" in to_do_list:
    print("Don't forget to pay the utilty bills")
    
print("To do lists remaining")
for task in to_do_list:
    print(f"-{task}")
# Out:
# Don't forget to pay the utilty bills
# To do lists remaining
# -Buy Groceries
# -pay_bills
# -scheduled meeting
# -Go for a Run
