# %%
"""
    tuples:
    tuples are ordered collections of items that are immutable. They are similar to lists,but theire immutabiltity makes them different.
"""
# Out:
# '\n    tuples:\n    tuples are ordered collections of items that are immutable. They are similar to lists,but theire immutabiltity makes them different.\n'

# %%
## creating a tuple

empty_tuple=()

print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst = list()
print(type(lst))
tpl = tuple()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
numbers = tuple([1,2,3,4,5,6])
numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
list((1,2,3,4,5,6))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
mixed_tuple = (1,"hello",3.14,True)
print(mixed_tuple)
# Out:
# (1, 'hello', 3.14, True)

# %%
## accessing Tuple Elements

numbers
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
numbers[2]
# Out:
# 3

# %%
print(numbers[2])
print(numbers[-1])
# Out:
# 3
# 6

# %%
numbers[0:4]
# Out:
# (1, 2, 3, 4)

# %%
numbers[::-1]
# Out:
# (6, 5, 4, 3, 2, 1)

# %%
## Tuples Operations

concatenation_tuple = mixed_tuple + numbers
print(concatenation_tuple)
# Out:
# (1, 'hello', 3.14, True, 1, 2, 3, 4, 5, 6)

# %%
mixed_tuple*3
# Out:
# (1, 'hello', 3.14, True, 1, 'hello', 3.14, True, 1, 'hello', 3.14, True)

# %%
numbers*3
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)

# %%
## Immutable Nature of Tuples

lst=[1,2,3,4,5]
print(lst)

lst[1] = "krish"
print(lst)
# Out:
# [1, 2, 3, 4, 5]
# [1, 'krish', 3, 4, 5]

# %%
# numbers[1] = "krish"  this will give error

# %%
## Tuples Methods
print(numbers.count(1))
print(numbers.index(3))
# Out:
# 1
# 2

# %%
numbers
# Out:
# 2

# %%
## packing and unpacking tuples 

packed_tuple = 1,"hello",3.14
print(packed_tuple)
# Out:
# (1, 'hello', 3.14)

# %%
## Unpacking a tuple
a,b,c=packed_tuple
print(a)
print(b)
print(c)
# Out:
# 1
# hello
# 3.14

# %%
## unpacking with *

numbers = (1,2,3,4,5,6)
first,*middle,last = numbers
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %%
## nested Tuple

lst=[[1,2,3,4],[6,7,8,9],[1,"Hello",3.14,"c"]]
lst[0]
# Out:
# [1, 2, 3, 4]

# %%
lst[0][2]
lst[0][0:3]
# Out:
# [1, 2, 3]

# %%
lst=[[1,2,3,4],[6,7,8,9],(1,"Hello",3.14,"c")]
lst[2][0:3]
# Out:
# (1, 'Hello', 3.14)

# %%
nested_tuple = ((1,2,3),("a","b","c"),(True,False))

## access the elements inside a tuple
print(nested_tuple[0])
print(nested_tuple[1][2])
# Out:
# (1, 2, 3)
# c

# %%
## iterating over nested tuples
for sub_tuple in nested_tuple:
    for item in sub_tuple:
        print(item,end=" ")
    print()
# Out:
# 1 2 3
# a b c
# True False
