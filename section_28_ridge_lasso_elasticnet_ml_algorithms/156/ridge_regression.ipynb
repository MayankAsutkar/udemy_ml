# %% [markdown]
# ## ridge_regression

# %% [markdown]
# overfitting : wrt to traning data accuracy is very high -> low bias
#
# test data -> acc very less -> high variance
#
# ridge regression is also called as (L2 rgression)
#
# used to reduce overfitting
#
# we have to make sure our cost function never becomes zero
#
# to ensure these we add two hyperparameters lambda and slope
#
# ![image.png](attachment:image.png)
#
# adding these parameters ensure that no line actually matches tyeh original best fit line.
#
# the global minima is shifted
