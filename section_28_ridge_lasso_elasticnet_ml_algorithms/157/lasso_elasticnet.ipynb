# %% [markdown]
# ## lasso_regrression  and elastic net regression

# %% [markdown]
# lasso regreession (feature selection) -> (L1 regression)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# so feature selction is the process in which we try to reduce a coefficient of a feature to zero.
# these is known as feature selection

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# when we have many features the we can use lasso regression

# %% [markdown]
# ## elastic net regression

# %% [markdown]
# here we combine both lasso and ridge regression

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hyperparameter tuning the linear regression
