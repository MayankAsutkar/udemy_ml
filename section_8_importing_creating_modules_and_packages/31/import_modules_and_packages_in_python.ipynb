# %% [markdown]
# in py modules and packages help organise and reuse the code.

# %%
import math
math.sqrt(23)
# Out:
# 4.795831523312719

# %%
from math import sqrt,pi
print(pi)
print(math.sqrt(pi))
# Out:
# 3.141592653589793
# 1.7724538509055159

# %%
import numpy as np #here np is allies
np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
from math import * #this will import everything from math
sqrt(16)
print(pi)
# Out:
# 3.141592653589793

# %%
import sys
import os
sys.path.append(os.path.abspath("../packages"))
from maths import addition
addition(2,3)
# Out:
# 5
