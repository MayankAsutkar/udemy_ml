# %% [markdown]
# python's stndard library is a vast collection of modules and packages that come bundled with python, providing a wide range of functionalities out of the box. Here's an overview of some of the most commonly used modules and packages in the python standard library.

# %%
import array
arr = array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 6
# cherry

# %% [markdown]
# ### file and directory access

# %%
import os
print(os.getcwd())#get current working directory
# Out:
# c:\Users\mayan\OneDrive\Documents\GitHub\udemy_ml\section_8_importing_creating_modules_and_packages\32

# %%
os.mkdir('test_dir')

# %%
open("file.txt","w").close()
## this creates file using os

# %% [markdown]
# highlevel operations on files and collection of files

# %%
import shutil
shutil.copyfile('source.txt','destinationn.txt')
## this creates destination.txt copy of source.txt
# Out:
# 'destinationn.txt'

# %% [markdown]
#  data serialization

# %%
import json
data = {'name':'krish','age':25}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "krish", "age": 25}
# <class 'str'>
# {'name': 'krish', 'age': 25}
# <class 'dict'>

# %% [markdown]
# csv

# %%
import csv

with open('example.csv',mode='w',newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['names','age'])
    writer.writerow(['mayank','19'])
    
with open('example.csv',mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['names', 'age']
# ['mayank', '19']

# %% [markdown]
# datetime

# %%
from datetime import datetime,timedelta

now = datetime.now()
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2026-03-14 02:15:13.655208
# 2026-03-13 02:15:13.655208

# %% [markdown]
# time

# %%
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1773434772.5631905
# 1773434774.5788443

# %% [markdown]
# regular expression

# %%
import re
pattern = r'\d+' ## here d is digits
text = 'There are 123 apples'
match = re.search(pattern,text)
print(match.group())
# Out:
# 123
