# %% [markdown]
# ## multi threading and multi processing

# %% [markdown]
# program -> A program is a sequence of instructions written in programming language.
#
# ex : google chrome -> exe file <- program   ----> how browser should work.
#      word,
#      excel
#
# Process :- A process is simply an instance of a program that is being executed.
#
# code segment | Data segment | Heap
#
#     Stack       |     Registers
#
# seperate memory space
# * one process cannot corrupt another procss
# * every process has seperate I/O requirements
# * increased execution time between processes due to switching

# %% [markdown]
# ## Threads
#
# A thread is a unit of execution within a process
#
# * single threaded process
# * The thread will be sharing the code segment,data segment and heap from the preocess itself.
#
# * multithreaded process :
# we will have multiple threads
# * each thread will have it's own stack and register
