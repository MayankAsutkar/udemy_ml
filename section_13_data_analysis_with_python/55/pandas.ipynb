# %% [markdown]
# # pandas dataframe and series

# %% [markdown]
# Pandas is a powerful data manipulation library in Python, widely used for data analysis and data cleaning. It provides two primary data structures: Series and DataFrame. A Series is a one-dimensional array-like object, while a DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns).

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
## series
# pandas series is a 1d array like object that can hold any data type. It is similar to a column in a table.

# %%
data = [1,2,3,4,5]
series = pd.Series(data)
print("Series\n",series)
print(type(series))
# Out:
# Series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
## series from dictionary

data = {'a': 1,'b': 2,'c': 3}
series_dict = pd.Series(data)
print(series_dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = [10,20,30]
index = ['a','b','c']
pd.Series(data,index = index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
## data frame:
## create a dataframe from a dictionary of list

data = {
    "Name" : ['Krish','John','Jack'],
    'Age' : [25,30,45],
    'City' : ["Bangalore" , 'New York' , "Florida"]
}
df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New York
# 2   Jack   45    Florida
# <class 'pandas.core.frame.DataFrame'>

# %%
import numpy as np
df1 = np.array(df)
df1
# Out:
# array([['Krish', 25, 'Bangalore'],
#        ['John', 30, 'New York'],
#        ['Jack', 45, 'Florida']], dtype=object)

# %%
## create a dataframe from a list of dictionaries

data = [
    {"Name" : 'Krish','Age': 32 , "City" : "Bangalore"},
    {"Name" : 'John','Age': 30 , "City" : "manpada"},
    {"Name" : 'mayank','Age': 20 , "City" : "Bombay"},
    {"Name" : 'jackie','Age': 10 , "City" : "manpada"}
]

df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#      Name  Age       City
# 0   Krish   32  Bangalore
# 1    John   30    manpada
# 2  mayank   20     Bombay
# 3  jackie   10    manpada
# <class 'pandas.core.frame.DataFrame'>

# %%
df= pd.read_csv('sales_data.csv')
df.head()
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
df.tail(5)
# Out:
#      Transaction ID        Date Product Category  \
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
# 236                        Nike Air Force 1 Sneakers           3       90.00
# 237           The Handmaid's Tale by Margaret Atwood           3       10.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
# 239                       Yeti Rambler 20 oz Tumbler           2       29.99
#
#      Total Revenue         Region Payment Method
# 235         159.99         Europe         PayPal
# 236         270.00           Asia     Debit Card
# 237          32.97  North America    Credit Card
# ...

# %%
### accessing data from dataframe
df
# Out:
#      Name  Age       City
# 0   Krish   32  Bangalore
# 1    John   30    manpada
# 2  mayank   20     Bombay
# 3  jackie   10    manpada

# %%
df['Name']
# Out:
# 0     Krish
# 1      John
# 2    mayank
# 3    jackie
# Name: Name, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df.loc[0] ## row index
# Out:
# Name        Krish
# Age            32
# City    Bangalore
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# Name        Krish
# Age            32
# City    Bangalore
# Name: 0, dtype: object

# %%
df.loc[0][0]
# Out:
# C:\Users\mayan\AppData\Local\Temp\ipykernel_5460\2527876973.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.loc[0][0]
# 'Krish'

# %%
df.iloc[0][1]
# Out:
# C:\Users\mayan\AppData\Local\Temp\ipykernel_5460\2309508539.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][1]
# np.int64(32)

# %%
df.iloc[0][2]
# Out:
# C:\Users\mayan\AppData\Local\Temp\ipykernel_5460\2519637664.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][2]
# 'Bangalore'

# %%
## accessing a specified elements

df.at[1,'Age']
# Out:
# np.int64(30)

# %%
df.at[2,'Name']
# Out:
# 'mayank'

# %%
## accessing a specified element using iat

df.iat[2,2]
# Out:
# 'Bombay'

# %%
### data manipulation with dataframe

df
# Out:
#      Name  Age       City
# 0   Krish   32  Bangalore
# 1    John   30    manpada
# 2  mayank   20     Bombay
# 3  jackie   10    manpada

# %%
## adding new column
df['Salary'] = [50000,60000,70000,10000]
df
# Out:
#      Name  Age       City  Salary
# 0   Krish   32  Bangalore   50000
# 1    John   30    manpada   60000
# 2  mayank   20     Bombay   70000
# 3  jackie   10    manpada   10000

# %%
## remove a column
df.drop('Salary',axis = 1) ## by defaualt axis is 0 which means row , 1 : column
# Out:
#      Name  Age       City
# 0   Krish   32  Bangalore
# 1    John   30    manpada
# 2  mayank   20     Bombay
# 3  jackie   10    manpada

# %%
df
# Out:
#      Name  Age       City  Salary
# 0   Krish   32  Bangalore   50000
# 1    John   30    manpada   60000
# 2  mayank   20     Bombay   70000
# 3  jackie   10    manpada   10000

# %%
df = df.drop('Salary',axis = 1)
df
# Out:
#      Name  Age       City
# 0   Krish   32  Bangalore
# 1    John   30    manpada
# 2  mayank   20     Bombay
# 3  jackie   10    manpada

# %%
## anothe method to remove salary permnanently is inplace = true

df['Salary'] = [50000,60000,70000,10000]
df
# Out:
#      Name  Age       City  Salary
# 0   Krish   32  Bangalore   50000
# 1    John   30    manpada   60000
# 2  mayank   20     Bombay   70000
# 3  jackie   10    manpada   10000

# %%
df.drop('Salary',inplace = True,axis = 1)
df
# Out:
#      Name  Age       City
# 0   Krish   32  Bangalore
# 1    John   30    manpada
# 2  mayank   20     Bombay
# 3  jackie   10    manpada

# %%
## add age to the column
df['Age'] = df['Age'] + 1
df
# Out:
#      Name  Age       City
# 0   Krish   33  Bangalore
# 1    John   31    manpada
# 2  mayank   21     Bombay
# 3  jackie   11    manpada

# %%
df.drop(0)
df
# Out:
#      Name  Age       City
# 0   Krish   33  Bangalore
# 1    John   31    manpada
# 2  mayank   21     Bombay
# 3  jackie   11    manpada

# %%
df.drop(0,inplace = True)
df
# Out:
#      Name  Age     City
# 1    John   31  manpada
# 2  mayank   21   Bombay
# 3  jackie   11  manpada

# %%
df = pd.read_csv('sales_data.csv')
df
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
#Display the daat types of each column
print("Data types:\n",df.dtypes)
print()
#Describe the DataFrame
print("Statistical summary:\n",df.describe())
# Out:
# Data types:
#  Transaction ID        int64
# Date                 object
# Product Category     object
# Product Name         object
# Units Sold            int64
# Unit Price          float64
# Total Revenue       float64
# Region               object
# Payment Method       object
# dtype: object
#
# Statistical summary:
#         Transaction ID  Units Sold   Unit Price  Total Revenue
# count       240.00000  240.000000   240.000000     240.000000
# mean      10120.50000    2.158333   236.395583     335.699375
# std          69.42622    1.322454   429.446695     485.804469
# min       10001.00000    1.000000     6.500000       6.500000
# 25%       10060.75000    1.000000    29.500000      62.965000
# 50%       10120.50000    2.000000    89.990000     179.970000
# 75%       10180.25000    3.000000   249.990000     399.225000
# max       10240.00000   10.000000  3899.990000    3899.990000
