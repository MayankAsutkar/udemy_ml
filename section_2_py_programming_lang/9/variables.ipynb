# %%
a = 100

# %%
# declaring ans assigning variables
age = 32
height = 6.1
name = "Krish"
is_student = True

print("age: ",age)
print("height: ",height)
print("name: ",name)
print("is_student: ",is_student)
# Out:
# age:  32
# height:  6.1
# name:  Krish
# is_student:  True

# %%
# naming conventions
# variables names should be descriptive
# they must start with a letter or an '_' nad contains letters,numbers and underscores
# vraiables names case sensitive

first_name = "krish"
last_name = "naik"

# %%
name = "krish"
Name = "krish"
name == Name
# Out:
# True

# %%
# understanding varaible types
# python is dynamically typed,type of a vraible is determined at runtime
age = 25 #int
height = 6.1 #float
name = "Krish" # str
is_student=  True # boolean

# %%
# Type checking and conversion
type(height)
# Out:
# float

# %%
age = 25
print(type(age))

# type converion
age_str = str(age)
print(age_str)
print(type(age_str))
# Out:
# <class 'int'>
# 25
# <class 'str'>

# %%
age='25'
print(type(int(age)))
# Out:
# <class 'int'>

# %%
name = "krish"
int(name) # will give error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 name = "krish"
# ----> 2 int(name) # will give error
#
# ValueError: invalid literal for int() with base 10: 'krish'

# %%
height= 6.1
type(height)
# Out:
# float

# %%
int(height)
# Out:
# 6

# %%
float(int(height))
# Out:
# 6.0

# %%
## dynamic typing
## py allows the type of variable to change as the program executes
var = 10
print(var,type(var))

var = "hello"
print(var,type(var))

var = 3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 3.14 <class 'float'>

# %%
## input

age = input("What is the age")
print(age,type(age))

age = int(input("What is the age"))
print(age,type(age))
# Out:
# 23 <class 'str'>
# 24 <class 'int'>

# %%
num1 = int(input("Enter the 1 st number"))
num2 = int(input("Enter the 2 nd number"))

sum = num1+ num2
difference = num1 - num2
pro = num1*num2
quotient = num1/num2

print("sum : ",sum)
print("differnece : ",difference)
print("Product : ",pro)
print("Quotient : ",quotient)
# Out:
# sum :  26
# differnece :  22
# Product :  48
# Quotient :  12.0
