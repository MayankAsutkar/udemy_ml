# %%
## function is a block of code that performs a specific task.  functions help in organizing code,reusing code, and improving readibility.

def function_name(parameters):
    """Docstring"""
    # function body
    return expression

# %%
## why functions?
num = 24
if num%2 == 0:
    print("the number is even")
else:
    print("the  number is odd")
# Out:
# the number is even

# %%
def even_or_odd(num):
    """This functions finds even or odd"""
    if num%2 == 0:
        print("the number is even")
    else:
        print("the number is odd")

# %%
# call this function
even_or_odd(24)
even_or_odd(25)
# Out:
# the number is even
# the number is odd

# %%
## function with mulyiple  parameters

def add(a,b):
    """This will add two numbers"""
    return a + b

result = add(2,4)
print(result)
# Out:
# 6

# %%
## default parameters:

def greet(name="Guest"):
    print(f"hello {name} welcome to paradise")
    
greet("krish")
greet() # thsi will take default parameters
# Out:
# hello krish welcome to paradise
# hello Guest welcome to paradise

# %%
## varaiable length arguments
## positional and keyword arguments

def print_numbers(*args):
    for number in args:
        print(number)

# %%
print_numbers(1,2,3,4,5,6,6,"mayank") ## positional arguments
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 6
# mayank

# %%
## keywords arguments

def print_details(**kwargs):
    for key,value in kwargs.items():
        print(f"{key}:{value}")
        
print_details(name = "maya",age="19",country="madagascar")
# Out:
# name:maya
# age:19
# country:madagascar

# %%
def print_details(*args,**kwargs):
    for val in args:
        print(f"positional argument : {val}")
        
    for key,value in kwargs.items():
        print(f"{key}:{value}")
        
print_details(1,2,3,"maya","john",name = "maya",age="19",country="madagascar")
# Out:
# positional argument : 1
# positional argument : 2
# positional argument : 3
# positional argument : maya
# positional argument : john
# name:maya
# age:19
# country:madagascar

# %%
### return statements

def multiply(a,b):
    return a*b

multiply(2,3)
# Out:
# 6

# %%
def multiply(a,b):
    return a*b,a    ## can return multiple parameters

multiply(2,3)
# Out:
# (6, 2)
